# %% [markdown]
# <a href="https://colab.research.google.com/github/khou128/QM2/blob/main/Project_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NLP Analysis of Critic Reviews of Movies

# %% [markdown]
# **Question:**
#
# 1. Are reviews of popular/non-popular films more uniform or diverse in nature?
#
# 2. Do positively rated critic reviews relate to box office success?

# %% [markdown]
# **Methodology:**
#
# In order to answer these questions, I shall conduct word frequency and sentiment analysis from Natural Language Processing (NLP) to the movies with highest and lowest revenue.
#
# The dataset for gathering the ranks of movies by revenue is TMDB 5000 Movie Dataset (The Movie Database, 2017). The original dataset is not ranked in terms of revenue. Hence, I shall clean the dataset first to find out the top 5 and bottom 5 films, according to the value of renevue they made.
#
# Then, I shall scarpe critic movies reviews of these 10 movies from Rotten Tomatoes, a trusted measurement website of quality for Movies & TV (Rotten Tomatoes, 2008). The video tutorial I follow to learn to scrape can be found on Youtube (Aliens, 2020). I use a Chrome extension called 'Instant Data Scraper'. The extension extracts data from web pages and exports it as Excel or CSV files (Instant Data Scraper, 2023). After scraping the reviews and turn them into csv files, I will upload them to Github for the NLP analysis.
#
# There are different types of reviews on Rotten Tomatoes. I deliberately choose to analysis critic reviews, since audience reviews are often repetitive as they are generated by bots from time to time. This reduces the reliability of audience reviews comparing to critic reviews. Further, critic reviews are written by professionalists approved by Rotten Tomatoes. This increases the quality of the reviews that I will analyse.
#
# For word frequency analysis, I aim to find out if the critics in general speak highly of the movies with higher revenues and vice versa, through observing the top 20 words written in the critic reviews. This methodology helps to answer the first question: 'Are reviews of popular/non-popular films more uniform or diverse in nature?'.
#
# However, word frequency analysis does not vivdly show the extent of subjectivity of critic reviews. Hence, collective sentiment analysis shall be conducted for the top 5 and bottom 5 movies. This helps answer the second question:'Do positively rated critic reviews relate to box office success?'.

# %% [markdown]
# # 1. Word Frequency Analysis for Film Critic Reviews

# %% [markdown]
# First, I will clean the TMDB 5000 Movies dataset to rank them from highest revenue to the lowest.

# %%
import pandas as pd

# %% [markdown]
# Here is the original version of the dataset:

# %%
url_1 = 'https://raw.githubusercontent.com/khou128/QM2/main/tmdb_5000_movies.csv'
df_TMDB = pd.read_csv(url_1)
df_TMDB
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %% [markdown]
# Now, the revenue column can be found, and cleaning shall be done:

# %%
df_TMDB_sorted = df_TMDB.sort_values('revenue',ascending=False)
df_TMDB_sorted
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 25    200000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 16    220000000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 28    150000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 44    190000000                     [{"id": 28, "name": "Action"}]
# ...         ...                                                ...
# 3200          0  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
# 3199          0  [{"id": 53, "name": "Thriller"}, {"id": 9648, ...
# 3197    6500000  [{"id": 80, "name": "Crime"}, {"id": 18, "name...
# 3194    9000000  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                homepage      id  \
# 0           http://www.avatarmovie.com/   19995
# 25          http://www.titanicmovie.com     597
# ...

# %% [markdown]
# To see the names of the movies and their revenue more visually pleasing, I will conduct a further step to clean the dataset:

# %%
selected_columns = df_TMDB_sorted[['original_title','release_date', 'revenue', ]]
selected_columns
# Out:
#                                 original_title release_date     revenue
# 0                                       Avatar   2009-12-10  2787965087
# 25                                     Titanic   1997-11-18  1845034188
# 16                                The Avengers   2012-04-25  1519557910
# 28                              Jurassic World   2015-06-09  1513528810
# 44                                   Furious 7   2015-04-01  1506249360
# ...                                        ...          ...         ...
# 3200                           La Fille du RER   2009-03-18           0
# 3199  Red Riding: In the Year of Our Lord 1974   2009-02-28           0
# 3197                        Flammen & Citronen   2008-03-25           0
# 3194                            All or Nothing   2002-05-17           0
# 4802                         My Date with Drew   2005-08-05           0
#
# [4803 rows x 3 columns]

# %% [markdown]
# The revenue for the majority seems fine. However, we can see that especially the last few movies do not indicate any revenue at all, which is impossible. Perhaps there is no data of revenue collected for them. Hence, I will exclude the movies with 0 revenue and improve my dataframe:

# %%
filtered_df = selected_columns[selected_columns['revenue'] != 0]

print(filtered_df)
# Out:
#                original_title release_date     revenue
# 0                      Avatar   2009-12-10  2787965087
# 25                    Titanic   1997-11-18  1845034188
# 16               The Avengers   2012-04-25  1519557910
# 28             Jurassic World   2015-06-09  1513528810
# 44                  Furious 7   2015-04-01  1506249360
# ...                       ...          ...         ...
# 2933                 F.I.S.T.   1978-04-26          11
# 3428                     Bats   1999-10-22          10
# 3419             Bran Nue Dae   2009-08-09           7
# 3875  Dreaming of Joseph Lees   1999-10-29           7
# 3372             Split Second   1992-05-01           5
#
# [3376 rows x 3 columns]

# %% [markdown]
# I will now find the names of the top 5 and bottom 5 movies:

# %%
print(filtered_df.head())
# Out:
#     original_title release_date     revenue
# 0           Avatar   2009-12-10  2787965087
# 25         Titanic   1997-11-18  1845034188
# 16    The Avengers   2012-04-25  1519557910
# 28  Jurassic World   2015-06-09  1513528810
# 44       Furious 7   2015-04-01  1506249360

# %%
print(filtered_df.tail())
# Out:
#                original_title release_date  revenue
# 3131              Hross í oss   2013-08-30       11
# 2933                 F.I.S.T.   1978-04-26       11
# 3428                     Bats   1999-10-22       10
# 3419             Bran Nue Dae   2009-08-09        7
# 3875  Dreaming of Joseph Lees   1999-10-29        7

# %% [markdown]
# Now we have got the top and bottom 5 movies to analyse! I shall scrape critic reviews of them from Rotten Tomatoes, and convert the list of reviews into csv files. I have kept the release_date column, as that helps me to find the correct movie on Rotten Tomatoes, just in case there are movies with the same titles but published in different years, produced by different organisations.
#
# Top 5 (from highest to lowest):
# 1. Avatar (2009)
# 2. Titanic (1997)
# 3. The Avengers (2012)
# 4. Jurassic World (2015)
# 5. Furious 7 (2015)
#
# Bottom 5 (from lowest to highest):
# 1. Split Second (1992)
# 2. Dreaming of Joseph Lees (1999)
# 3. Bran Nue Dae (2009)
# 4. Bats (1999)
# 5. F.I.S.T. (1978)
#
# I will try-out the top 2 films first to see how the word frequency analysis is going:

# %%
#Avatar:
url = 'https://raw.githubusercontent.com/khou128/QM2/main/critics%20for%20Avatar.csv'
df = pd.read_csv(url)
df.head
# Out:
# <bound method NDFrame.head of           display-name          publication  \
# 0         Brian Eggert    Deep Focus Review
# 1            Zach Pope    Zach Pope Reviews
# 2     Douglas Davidson  Elements of Madness
# 3         Allison Rose          FlickDirect
# 4         Matt Brunson          Film Frenzy
# ..                 ...                  ...
# 307     Kirk Honeycutt   Hollywood Reporter
# 308  Chris Hewitt (UK)      Empire Magazine
# 309          Anna Keir     Independent (UK)
# 310          Wendy Ide           Times (UK)
# 311          The Sneak         The Sun (UK)
#
#                                            review-text  \
# 0    To be sure, this is an engaging experience in ...
# 1    STUNNING epic.  Zoe Saldana performance… A fan...
# 2    It’s the world of Pandora married to the groun...
# 3    Cameron is a master filmmaker whose movies wil...
# 4    While the visuals might rate four stars, the s...
# ..                                                 ...
# ...

# %% [markdown]
# We are only interested in the reviews:

# %%
print(df['review-text'])
# Out:
# 0      To be sure, this is an engaging experience in ...
# 1      STUNNING epic.  Zoe Saldana performance… A fan...
# 2      It’s the world of Pandora married to the groun...
# 3      Cameron is a master filmmaker whose movies wil...
# 4      While the visuals might rate four stars, the s...
#                              ...
# 307    The screen is alive with more action and the s...
# 308    It's a world, not to give too much away, that ...
# 309    There are myriad moments of beauty and of poig...
# 310    Avatar is an overwhelming, immersive spectacle...
# 311    It's a 3D movie people will look back on in ye...
# Name: review-text, Length: 312, dtype: object

# %% [markdown]
# The visualisation of word frequency counts can be created:

# %%
import matplotlib.pyplot as plt
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
from nltk.corpus import stopwords
from matplotlib import cm
import numpy as np

text_data = ' '.join(df['review-text'].dropna())
words = word_tokenize(text_data)
stop_words = set(stopwords.words('english'))
words = [word.lower() for word in words if word.isalpha() and word.lower() not in stop_words]
freq_dist = FreqDist(words)
top_words = freq_dist.most_common(20)
colormap = cm.get_cmap('rainbow', len(top_words))
plt.figure(figsize=(10, 6))
bars = plt.bar(*zip(*top_words), color=colormap(range(len(top_words))), width=0.6, align='center')
plt.xlabel('Words', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.title('Top Words for Avatar Critic Reviews', fontsize=16, fontweight='bold')
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.gca().set_facecolor('#F5F5F5')
plt.grid(axis='y', linestyle='--', alpha=0.7)
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.01, round(yval, 2), ha='center', va='bottom', fontsize=8)
plt.show()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# <ipython-input-69-a591d87bc50d>:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colormap = cm.get_cmap('rainbow', len(top_words))

# %%
#Titanic:
url1 = 'https://raw.githubusercontent.com/khou128/QM2/main/Titanic.csv'
df1 = pd.read_csv(url1)
df1.head
# Out:
# <bound method NDFrame.head of            display-name                    publication  \
# 0         Preston Barta                  Fresh Fiction
# 1          Allison Rose                    FlickDirect
# 2     Patricia Karounos                     Refinery29
# 3       David Griffiths       Subculture Entertainment
# 4      Danielle Solzman            Solzy at the Movies
# ..                  ...                            ...
# 250  Jonathan Rosenbaum                 Chicago Reader
# 251         Roger Ebert              Chicago Sun-Times
# 252          Jeff Simon                   Buffalo News
# 253     Dennis Schwartz  Dennis Schwartz Movie Reviews
# 254          Scott Nash              Three Movie Buffs
#
#                                            review-text  \
# 0    'Titanic' isn’t shy about reaching for the hea...
# 1    Cameron is skilled at creating successful film...
# 2    An awe-inspiring, life-changing love — the kin...
# ...

# %%
text_data = ' '.join(df1['review-text'].dropna())
words = word_tokenize(text_data)
stop_words = set(stopwords.words('english'))
words = [word.lower() for word in words if word.isalpha() and word.lower() not in stop_words]
freq_dist = FreqDist(words)
top_words = freq_dist.most_common(20)
colormap = cm.get_cmap('rainbow', len(top_words))
plt.figure(figsize=(10, 6))
bars = plt.bar(*zip(*top_words), color=colormap(range(len(top_words))), width=0.6, align='center')
plt.xlabel('Words', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.title('Top Words for Titanic Critic Reviews', fontsize=16, fontweight='bold')
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.gca().set_facecolor('#F5F5F5')
plt.grid(axis='y', linestyle='--', alpha=0.7)
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.01, round(yval, 2), ha='center', va='bottom', fontsize=8)
plt.show()
# Out:
# <ipython-input-42-8a210457d743>:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colormap = cm.get_cmap('rainbow', len(top_words))

# %% [markdown]
# However, from these two charts we can see that the most mentioned words in the critics reviews are mainly the words from the movie title or the names of the producer or the actors, such as 'Avatar', 'titanic', and 'james'; or words unrelated such as 'film' and 'movies'. These words are not really what we are interested in to investigate the popularity of the films. Hence, here is the modified version of the word frequency charts:

# %%
#Word frequency for Avatar:
text_data = ' '.join(df['review-text'].dropna())
words = word_tokenize(text_data)
stop_words = set(stopwords.words('english'))
exclude_words = ['avatar', 'cameron' ,'james', 'film', 'films', 'movie', 'movies']  # Add the words to exclude
words = [word.lower() for word in words if word.isalpha() and word.lower() not in stop_words and word.lower() not in exclude_words] # Filter out stop words and excluded words
freq_dist = FreqDist(words)
top_words = freq_dist.most_common(20)
colormap = cm.get_cmap('rainbow', len(top_words))
plt.figure(figsize=(10, 6))
bars = plt.bar(*zip(*top_words), color=colormap(range(len(top_words))), width=0.6, align='center')
plt.xlabel('Words', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.title('Top Words for Avatar Critic Reviews', fontsize=16, fontweight='bold')
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.gca().set_facecolor('#F5F5F5')
plt.grid(axis='y', linestyle='--', alpha=0.7)
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.01, round(yval, 2), ha='center', va='bottom', fontsize=8)
plt.show()
# Out:
# <ipython-input-41-b7cf64ed09ea>:9: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colormap = cm.get_cmap('rainbow', len(top_words))

# %%
#Word frequency for Titanic:
text_data = ' '.join(df1['review-text'].dropna())
words = word_tokenize(text_data)
stop_words = set(stopwords.words('english'))
exclude_words = ['titanic', 'cameron', 'james', 'film', 'films', 'movie', 'movies']  # Add the words to exclude
words = [word.lower() for word in words if word.isalpha() and word.lower() not in stop_words and word.lower() not in exclude_words] # Filter out stop words and excluded words
freq_dist = FreqDist(words)
top_words = freq_dist.most_common(20)
colormap = cm.get_cmap('rainbow', len(top_words))
plt.figure(figsize=(10, 6))
bars = plt.bar(*zip(*top_words), color=colormap(range(len(top_words))), width=0.6, align='center')
plt.xlabel('Words', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.title('Top Words for Titanic Critic Reviews', fontsize=16, fontweight='bold')
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.gca().set_facecolor('#F5F5F5')
plt.grid(axis='y', linestyle='--', alpha=0.7)
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.01, round(yval, 2), ha='center', va='bottom', fontsize=8)
plt.show()
# Out:
# <ipython-input-40-2d25d25a5e2c>:9: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colormap = cm.get_cmap('rainbow', len(top_words))

# %% [markdown]
# These visualisations are now much better - the top 20 words they now show can illustrate that in general, critic reviews speak highly of the movies with top box offices. I will now use the modified version of the word frequency chart code for the rest of the films. I will aim to combine the top 5 films reviews together to one dataset, and the bottm 5 together, to see the most frequent words of their critic reviews respectively.

# %%
#The rest of the top 5 movies:
#The Avengers:
url2 = 'https://raw.githubusercontent.com/khou128/QM2/main/The%20Avengers.csv'
df2 = pd.read_csv(url2)


#Jurassic World
url3 = 'https://raw.githubusercontent.com/khou128/QM2/main/Jurassic%20World.csv'
df3 = pd.read_csv(url3)

#Furious 7
url4 = 'https://raw.githubusercontent.com/khou128/QM2/main/Furious%207.csv'
df4 = pd.read_csv(url4)

# %%
#Merge top 5 critic reviews to one data frame:
top5 = pd.concat([df,df1,df2,df3,df4])

# %%
#Visualise the word frequency for top 5, excluding some unrelated words:
text_data = ' '.join(top5['review-text'].dropna())
words = word_tokenize(text_data)
stop_words = set(stopwords.words('english'))
exclude_words = ['film', 'films', 'movie', 'movies', 'avatar', 'titanic', 'cameron', 'james', 'jurassic', 'avengers', 'furious', 'world', 'one', 'whedon']  # Add the words to exclude
words = [word.lower() for word in words if word.isalpha() and word.lower() not in stop_words and word.lower() not in exclude_words]
freq_dist = FreqDist(words)
top_words = freq_dist.most_common(20)
colormap = cm.get_cmap('Reds_r', len(top_words))
plt.figure(figsize=(10, 6))
bars = plt.bar(*zip(*top_words), color=colormap(range(len(top_words))), width=0.6, align='center')
plt.xlabel('Words', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.title('Top Words from Critic Reviews for TMDB Top 5 (Highest Revenue) Movies', fontsize=16, fontweight='bold')
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.gca().set_facecolor('#F5F5F5')
plt.grid(axis='y', linestyle='--', alpha=0.7)
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval + 0.01, round(yval, 2), ha='center', va='bottom', fontsize=8)
plt.show()
# Out:
# <ipython-input-79-5a20ed1a6fc4>:9: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colormap = cm.get_cmap('Reds_r', len(top_words))

# %% [markdown]
# We can see that it is mostly positive adjectives that associate with the top 5 movies, such as 'like', 'fun', and 'good'. Therefore, it can be interpreted that for popular movie reviews, they tend to be uniform in nature, and the reviews are mostly positive.
#
# I will now turn to the bottom 5 movie critic reviews from the TMDB list, and conduct the same word frequency analysis methodology.
#
# From the number of critic reviews for the bottom 5 movies, we can already see the lack of attention to these movies. For instance, 'Split Second' only has 4 critic reviews, two of them have no word comments at all. 'Dreaming of Joseph Lees' only has 14 reviews. The number of critic reviews are significantly fewer than that of the top revenue movies.

# %% [markdown]
# Due to the number of critic reviews for 'Split Second' being too small, I shall exclude this movie in my list and use the sixth lowest movie:

# %%
index_to_delete = 2
filtered_df = filtered_df.drop(index_to_delete)

# %%
print(filtered_df.tail())
# Out:
#                original_title release_date  revenue
# 3131              Hross í oss   2013-08-30       11
# 2933                 F.I.S.T.   1978-04-26       11
# 3428                     Bats   1999-10-22       10
# 3419             Bran Nue Dae   2009-08-09        7
# 3875  Dreaming of Joseph Lees   1999-10-29        7

# %%
#Scraped csv files from the bottom 5 movies:
#Dreaming of Joseph Lees :
url5 = 'https://raw.githubusercontent.com/khou128/QM2/main/Dreaming%20of%20Joseph%20Lees%20.csv'
df5 = pd.read_csv(url5)

#Bran Nue Dae:
url6 = 'https://raw.githubusercontent.com/khou128/QM2/main/Bran%20Nue%20Dae.csv'
df6 = pd.read_csv(url6)

#Bats:
url7 = 'https://raw.githubusercontent.com/khou128/QM2/main/%20%20Bats%20.csv'
df7 = pd.read_csv(url7)

#F.I.S.T.:
url8 = 'https://raw.githubusercontent.com/khou128/QM2/main/F.I.S.T..csv'
df8 = pd.read_csv(url8)

#Hross í oss:
url9 = 'https://raw.githubusercontent.com/khou128/QM2/main/Hross%20i%CC%81%20oss%20.csv'
df9 = pd.read_csv(url9)

# %%
#Merge bottom 5 critic reviews to one data frame:
bottom5 = pd.concat([df5,df6,df7,df8,df9])

# %%
text_data = ' '.join(bottom5['review-text'].dropna())
words = word_tokenize(text_data)
stop_words = set(stopwords.words('english'))
exclude_words = ['film', 'films', 'movie', 'movies', 'bran', 'nue', 'dae','bats','horses']
words = [word.lower() for word in words if word.isalpha() and word.lower() not in stop_words and word.lower() not in exclude_words]
freq_dist = FreqDist(words)
top_words = freq_dist.most_common(20)
colormap = cm.get_cmap('Blues_r', len(top_words))
plt.figure(figsize=(10, 6))
bars = plt.bar(*zip(*top_words), color=colormap(range(len(top_words))), width=0.6, align='center')
plt.xlabel('Words', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.title('Top Words from Critic Reviews for TMDB Bottom 5 (Lowest Revenue) Movies', fontsize=16, fontweight='bold')
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.gca().set_facecolor('#F5F5F5')
plt.grid(axis='y', linestyle='--', alpha=0.7)
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval + 0.01, round(yval, 2), ha='center', va='bottom', fontsize=8)

plt.show()
# Out:
# <ipython-input-78-e4cecf49788b>:8: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colormap = cm.get_cmap('Blues_r', len(top_words))

# %% [markdown]
# For the critic reviews for the bottom 5 movies, not much adjectives can be seen to determine whether these reviews are uniform or diverse in nature. 'Like' is a common word both appeared in the top and the bottom movies reviews, but I am cautious of interpreting this word, since it can both be an adjective and an adverb, depending on the context of the review.
#
# Most importantly, there are significantly fewer reviews for the movies with lower revenue. This actually answers the second question essentially in some ways: the number of reviews relate to the success of revenue gained by the movies. The higher the revenue gained by the movies, the more critic reviews there are. This in a way can suggest the popularity of the movies relate to the financial success of films positively.

# %% [markdown]
# # 2. Sentiment Analysis of Critic Reviews

# %% [markdown]
# In this section, sentiment analysis of the critic reviews shall be conducted in order to determine how postively/negatively are these critic reviews. This aims to answer the second question: 'Do positively rated critic reviews relate to box office success?'

# %%
# %%capture
# !pip install spacy
# !pip install scattertext
# !pip install tika
# !pip install spacytextblob

# %%
import spacy
import json
import pylab
from IPython.core.display import display, HTML
import nltk
from tika import parser
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from spacytextblob.spacytextblob import SpacyTextBlob

# %matplotlib inline
pylab.rcParams['figure.figsize'] = (10., 8.)
nlp = spacy.load("en_core_web_sm")
nlp.add_pipe('spacytextblob')

# %% [markdown]
# Here is an example try-out of using sentiment analysis to one critic review of Avatar:

# %%
text_of_77th_row = df.loc[76, 'review-text']

# apply the NLP pipeline to this text.
doc = nlp(text_of_77th_row)

print(text_of_77th_row)
print('Polarity: ', doc._.blob.polarity)
print('Subjectivity: ', doc._.blob.subjectivity)
print('Assessments: ', doc._.blob.sentiment_assessments.assessments)
# Out:
# Worthington and Saldana provide enough wattage to keep the film's human center alive and beating, while Cameron wraps their story in an armature of generally impressive 3D attractions as well as a righteousness that's touching yet all too simplistic
# Polarity:  0.14285714285714285
# Subjectivity:  0.4428571428571429
# Assessments:  [(['enough'], 0.0, 0.5, None), (['human'], 0.0, 0.1, None), (['center'], -0.1, 0.1, None), (['alive'], 0.1, 0.4, None), (['generally', 'impressive'], 1.0, 1.0, None), (['touching'], 0.5, 0.5, None), (['simplistic'], -0.5, 0.5, None)]

# %%
#Further, an overall score of the polarity and subjectivity for the top 5 and bottom 5:
from textblob import TextBlob
import pandas as pd

top5['Polarity'] = top5['review-text'].apply(lambda text: TextBlob(str(text)).sentiment.polarity)
top5['Subjectivity'] = top5['review-text'].apply(lambda text: TextBlob(str(text)).sentiment.subjectivity)

# Overall sentiment analysis for all texts
try:
    average_polarity = top5['Polarity'].mean()
    average_subjectivity = top5['Subjectivity'].mean()

    print('Overall Sentiment Analysis for top 5:')
    print('Average Polarity: ', average_polarity)
    print('Average Subjectivity: ', average_subjectivity)
except KeyError:
    print(f"Error: 'Polarity' or 'Subjectivity' columns not found in the DataFrame.")
# Out:
# Overall Sentiment Analysis for top 5:
# Average Polarity:  0.19334688944635753
# Average Subjectivity:  0.501645583198191

# %%
#Bottom 5:
bottom5['Polarity'] = bottom5['review-text'].apply(lambda text: TextBlob(str(text)).sentiment.polarity)
bottom5['Subjectivity'] = bottom5['review-text'].apply(lambda text: TextBlob(str(text)).sentiment.subjectivity)

# Overall sentiment analysis for all texts
try:
    average_polarity = bottom5['Polarity'].mean()
    average_subjectivity = bottom5['Subjectivity'].mean()

    print('Overall Sentiment Analysis for bottom 5:')
    print('Average Polarity: ', average_polarity)
    print('Average Subjectivity: ', average_subjectivity)
except KeyError:
    print(f"Error: 'Polarity' or 'Subjectivity' columns not found in the DataFrame.")
# Out:
# Overall Sentiment Analysis for bottom 5:
# Average Polarity:  0.11875718536810088
# Average Subjectivity:  0.47381096554071905

# %% [markdown]
# Before analysing the results, here are the definitions of polarity and subjectivity (Barai, 2021):
#
# The polarity score ranges from -1 to 1, with -1 indicating extremely negative words like 'disgusting,' 'awful,' and 'pathetic,' and 1 indicating highly positive words such as 'excellent' and 'best.'
#
# The subjectivity score ranges from 0 to 1, indicating the degree of personal opinion present. A higher subjectivity score, close to 1, suggests that the text is characterized by more personal opinions than factual information.
#
# From the sentiment analysis we can tell that the average polarity score of the top5 is higher than that of the bottom5, suggesting on average the critic reviews of the top5 movies are more positive than that of the bottom5. Hence, positively rated films relate to the financial success of films to a certain extent.
#
# The average subjectivity of the top5 reviews is slightly higher than that of the bottom5 movies. This indicates that the critic reviews for higher revenue movies are more subjective. However, 0.50 and 0.47 does not differ from each other that much. Additionally, the subjectivity score being in the middle suggests that the critic reviews in general are a combination between factual informationa and personal opinions. This is somewhat expected from film reviews overall. As a result, the sujectivity score does not show a great difference between the top5 and bottom5 movie reviews.

# %% [markdown]
# **Answer:**
#
# 1. Are reviews of popular/non-popular films more uniform or diverse in nature?
#
# Reviews of popular films in terms of word frequency suggests that they do not differ much from that of the non-popular films. However, it needs to be taken into account that the number of reviews of non-popular films are fewer than that of the popular films. Hence, there might not be enough information of the reviews gathered of the non-popular films to demonstrate the difference. The analysis done here does not show the whole picture of the reviews of all popular or non-popular films.
#
#
#
# 2. Do positively rated critic reviews relate to box office success?
#
# From the sentiment analysis, especially the polarity score difference between the top5 and bottom5 movies, it can be interpreted that to some extent, positively rated critic reviews relate to box office success.
